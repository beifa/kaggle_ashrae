# %% [markdown]
# <a href="https://colab.research.google.com/github/beifa/kaggle_ashrae/blob/master/Table_features_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
path = '/content/drive/My Drive/ASHRAE/data/'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls '/content/drive/My Drive/ASHRAE/data/'
# Out:
# building_metadata.csv		droped_fetures_by_2.csv  test2.hdf5
# data_test_before_fake.pkl	droped_fetures_by_3.csv  test_addTime.pkl.gz
# data_test_ends.pkl.gz		droped_fetures_by_4.csv  train.csv
# data_test.pkl.gz		droped_fetures_by_5.csv  train_full_fill.pkl.gz
# data_train_add_features.pkl.gz	droped_fetures_by_6.csv  weather_test.csv
# data_train_before_fake.pkl.gz	metadata_fillNAN.pkl.gz  weather_train.csv
# droped_fetures_by_2_1.csv	sample_submission.csv

# %%
#https://colab.research.google.com/notebooks/data_table.ipynb
# %load_ext google.colab.data_table
#%unload_ext google.colab.data_table

# %%
pd.read_csv(path + 'droped_fetures_by_2.csv', header=None,)
"""
Все признаки и я дропал рандомно из списка предположительно плохих
"""
# Out:
#                                                     0         1
# 0               mark_not_fill_dew_temperature---month  2.105070
# 1            rolling_back_h_dew_temperature---quarter  2.134787
# 2   rolling_back_h_dew_temperature---rolling_back_...  2.163430
# 3   mark_not_fill_cloud_coverage---rolling_back_h_...  2.150257
# 4                         precip_depth_1_hr---quarter  2.133113
# 5                       es---mark_not_fill_wind_speed  2.118015
# 6                month---mark_not_fill_wind_direction  2.102323
# 7   mark_not_fill_wind_speed---rolling_back_h_dew_...  2.131514
# 8   rolling_forw_dew_temperature---mark_not_fill_a...  2.161884
# 9   rolling_back_h_air_temperature---rolling_back_...  2.130263
# 10         rolling_back_h_f_dew_temperature---rec_dew  2.132199
# 11              es---rolling_back_h_f_air_temperature  2.124165
# 12  mark_not_fill_wind_direction---rolling_back_h_...  2.131731
# 13   rolling_forw_dew_temperature---precip_depth_1_hr  2.110223
# ...

# %%
pd.read_csv(path + 'droped_fetures_by_2_1.csv', header=None,)
# Out:
#                                0         1
# 0                dew_temperature  2.086055
# 1                 cloud_coverage  2.114685
# 2                     wind_speed  2.130427
# 3             sea_level_pressure  2.139190
# 4                             rh  2.102696
# 5                    floor_count  2.099604
# 6   rolling_forw_air_temperature  2.101534
# 7                      dayofyear  2.135641
# 8                           hour  2.129168
# 9                    building_id  2.970910
# 10                       weekday  2.153399
# 11                   square_feet  2.135360
# 12                wind_direction  2.145225
# 13                    year_built  2.132402
# 14                   primary_use  2.100354
# 15                       site_id  2.085341

# %%
pd.read_csv(path + 'droped_fetures_by_3.csv', header=None,)
# Out:
#                                                     0         1
# 0   air_temperature---rolling_forw_air_temperature...  2.013754
# 1                     weekday---site_id---floor_count  2.142908
# 2          wind_direction---site_id---air_temperature  2.024811
# 3       dayofyear---dew_temperature---air_temperature  1.998447
# 4           building_id---year_built---wind_direction  3.080686
# 5               site_id---rec_rh---sea_level_pressure  2.148753
# 6        dayofyear---floor_count---sea_level_pressure  2.160913
# 7                   building_id---dayofyear---site_id  2.393277
# 8                        hour---floor_count---site_id  2.137062
# 9                   wind_direction---rec_air---rec_rh  2.127246
# 10                        rh---dew_temperature---hour  2.128789
# 11                   building_id---floor_count---hour  2.812099
# 12  wind_direction---rolling_forw_air_temperature-...  2.003173
# 13                       dayofyear---rec_rh---rec_air  2.127047
# ...

# %%
pd.read_csv(path + 'droped_fetures_by_4.csv', header=None,)
# Out:
#                                                     0         1
# 0   air_temperature---rolling_forw_air_temperature...  1.994394
# 1   weekday---site_id---floor_count---rh---square_...  2.148641
# 2   wind_direction---site_id---air_temperature---w...  2.053532
# 3   dayofyear---dew_temperature---air_temperature-...  2.014965
# 4   building_id---year_built---wind_direction---re...  3.055179
# 5   site_id---rec_rh---sea_level_pressure---dayofy...  2.129664
# 6   dayofyear---floor_count---sea_level_pressure--...  2.160538
# 7   building_id---dayofyear---site_id---weekday---...  2.451783
# 8   hour---floor_count---site_id---rec_rh---dew_te...  2.082588
# 9   wind_direction---rec_air---rec_rh---square_fee...  2.138964
# 10  rh---dew_temperature---hour---wind_speed---rec...  2.132955
# 11  building_id---floor_count---hour---air_tempera...  2.820388
# 12  wind_direction---rolling_forw_air_temperature-...  2.013596
# 13  dayofyear---rec_rh---rec_air---building_id---a...  2.919049
# ...

# %%
pd.read_csv(path + 'droped_fetures_by_5.csv', header=None,)
# Out:
#                                                     0         1
# 0   air_temperature---rolling_forw_air_temperature...  2.021845
# 1   weekday---site_id---floor_count---rh---square_...  2.181222
# 2   wind_direction---site_id---air_temperature---w...  2.053259
# 3   dayofyear---dew_temperature---air_temperature-...  2.019211
# 4   building_id---year_built---wind_direction---re...  2.836751
# 5   site_id---rec_rh---sea_level_pressure---dayofy...  2.089249
# 6   dayofyear---floor_count---sea_level_pressure--...  2.111921
# 7   building_id---dayofyear---site_id---weekday---...  2.421699
# 8   hour---floor_count---site_id---rec_rh---dew_te...  2.139177
# 9   wind_direction---rec_air---rec_rh---square_fee...  2.124957
# 10  rh---dew_temperature---hour---wind_speed---rec...  2.784506
# 11  building_id---floor_count---hour---air_tempera...  2.715228
# 12  wind_direction---rolling_forw_air_temperature-...  2.642889
# 13  dayofyear---rec_rh---rec_air---building_id---a...  2.758201
# ...
